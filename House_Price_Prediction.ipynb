# %% [markdown]
# #**House Price Prediction**

# %%
import pandas as pd

# %%
df1= pd.read_csv("train.csv")
df1
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
df2=pd.read_csv('test.csv')
df2.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities  ... ScreenPorch PoolArea PoolQC  Fence MiscFeature  \
# 0         Lvl    AllPub  ...         120        0    NaN  MnPrv         NaN
# 1         Lvl    AllPub  ...           0        0    NaN    NaN        Gar2
# 2         Lvl    AllPub  ...           0        0    NaN  MnPrv         NaN
# 3         Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 4         HLS    AllPub  ...         144        0    NaN    NaN         NaN
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition
# ...

# %%
df1.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
df1=df1[['SalePrice','LotArea','BedroomAbvGr','BsmtFinSF2','BsmtFinSF1','MasVnrArea','GrLivArea','LowQualFinSF','2ndFlrSF','1stFlrSF','TotalBsmtSF','BsmtUnfSF','GarageArea','WoodDeckSF','OpenPorchSF','EnclosedPorch','3SsnPorch','ScreenPorch','PoolArea','FullBath','HalfBath']]

# %%
df1.head(10)
# Out:
#    SalePrice  LotArea  BedroomAbvGr  BsmtFinSF2  BsmtFinSF1  MasVnrArea  \
# 0     208500     8450             3           0         706       196.0
# 1     181500     9600             3           0         978         0.0
# 2     223500    11250             3           0         486       162.0
# 3     140000     9550             3           0         216         0.0
# 4     250000    14260             4           0         655       350.0
# 5     143000    14115             1           0         732         0.0
# 6     307000    10084             3           0        1369       186.0
# 7     200000    10382             3          32         859       240.0
# 8     129900     6120             2           0           0         0.0
# 9     118000     7420             2           0         851         0.0
#
#    GrLivArea  LowQualFinSF  2ndFlrSF  1stFlrSF  ...  BsmtUnfSF  GarageArea  \
# 0       1710             0       854       856  ...        150         548
# ...

# %%
df2.columns
# Out:
# Index(['LotArea', 'BedroomAbvGr', 'BsmtFinSF2', 'BsmtFinSF1', 'MasVnrArea',
#        'GrLivArea', 'LowQualFinSF', '2ndFlrSF', '1stFlrSF', 'TotalBsmtSF',
#        'BsmtUnfSF', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch',
#        '3SsnPorch', 'ScreenPorch', 'PoolArea', 'FullBath', 'HalfBath'],
#       dtype='object')

# %%
df2.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           4
# LotFrontage      227
# LotArea            0
#                 ...
# MiscVal            0
# MoSold             0
# YrSold             0
# SaleType           1
# SaleCondition      0
# Length: 80, dtype: int64

# %%
df1.isnull().sum()
# Out:
# SalePrice        0
# LotArea          0
# BedroomAbvGr     0
# BsmtFinSF2       0
# BsmtFinSF1       0
# MasVnrArea       8
# GrLivArea        0
# LowQualFinSF     0
# 2ndFlrSF         0
# 1stFlrSF         0
# TotalBsmtSF      0
# BsmtUnfSF        0
# GarageArea       0
# WoodDeckSF       0
# OpenPorchSF      0
# EnclosedPorch    0
# 3SsnPorch        0
# ScreenPorch      0
# PoolArea         0
# FullBath         0
# HalfBath         0
# dtype: int64

# %%
df2=df2[['LotArea','BedroomAbvGr','BsmtFinSF2','BsmtFinSF1','MasVnrArea','GrLivArea','LowQualFinSF','2ndFlrSF','1stFlrSF','TotalBsmtSF','BsmtUnfSF','GarageArea','WoodDeckSF','OpenPorchSF','EnclosedPorch','3SsnPorch','ScreenPorch','PoolArea','FullBath','HalfBath']]
df2.head()
# Out:
#    LotArea  BedroomAbvGr  BsmtFinSF2  BsmtFinSF1  MasVnrArea  GrLivArea  \
# 0    11622             2       144.0       468.0         0.0        896
# 1    14267             3         0.0       923.0       108.0       1329
# 2    13830             3         0.0       791.0         0.0       1629
# 3     9978             3         0.0       602.0        20.0       1604
# 4     5005             2         0.0       263.0         0.0       1280
#
#    LowQualFinSF  2ndFlrSF  1stFlrSF  TotalBsmtSF  BsmtUnfSF  GarageArea  \
# 0             0         0       896        882.0      270.0       730.0
# 1             0         0      1329       1329.0      406.0       312.0
# 2             0       701       928        928.0      137.0       482.0
# 3             0       678       926        926.0      324.0       470.0
# 4             0         0      1280       1280.0     1017.0       506.0
#
#    WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea  \
# ...

# %%
df1.dropna(inplace=True)
df1.shape
# Out:
# <ipython-input-31-4e35f59fab30>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.dropna(inplace=True)
# (1452, 21)

# %%
df2.dropna(inplace=True)
df2.shape
# Out:
# (1442, 20)

# %%
X_train=df1.drop('SalePrice',axis=1)
y_train=df1['SalePrice']

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_predict=model.predict(df1.iloc[:5,1:])
y_predict
# Out:
# array([207984.9140529 , 186924.09587508, 215434.00469634, 155701.01309919,
#        270539.401019  ])

# %%
y_predict=model.predict(df2)
y_predict
# Out:
# array([153863.81868413, 181353.47603284, 205036.06480268, ...,
#        168531.8097299 ,  85373.68010426, 242762.77016535])

# %%
print("Accuracy = ",model.score(X_train,y_train))
# Out:
# Accuracy =  0.7201849668857339
